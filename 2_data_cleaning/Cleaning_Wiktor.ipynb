# %%
# This file combines the 3 datasets into one final cleaned dataset

# %%
import pandas as pd
import numpy as np
import os

# Load datasets
data = pd.read_csv("/Users/wiktor/TIC/Spring2026-TIC/data/merged_prices_weather.csv")

# %%
# Print column names
print("Columns in the dataset:")
print(data.columns)
# Out:
# Columns in the dataset:
# Index(['soybean_Close', 'soybean_Volume', 'soybean_log_return', 'date',
#        'corn_Close', 'corn_Volume', 'corn_log_return', 'temperature_2m_mean',
#        'precipitation_sum', 'dew_point_2m_mean', 'cloud_cover_mean',
#        'cloud_cover_max', 'dew_point_2m_max', 'dew_point_2m_min',
#        'cloud_cover_min', 'apparent_temperature_mean',
#        'et0_fao_evapotranspiration_sum', 'relative_humidity_2m_mean',
#        'relative_humidity_2m_min', 'relative_humidity_2m_max',
#        'snowfall_water_equivalent_sum', 'pressure_msl_mean',
#        'pressure_msl_max', 'pressure_msl_min', 'surface_pressure_mean',
#        'surface_pressure_min', 'winddirection_10m_dominant',
#        'surface_pressure_max', 'wind_speed_10m_max', 'wind_gusts_10m_max',
#        'wind_speed_10m_mean', 'wind_gusts_10m_mean', 'wind_gusts_10m_min',
#        'wind_speed_10m_min', 'wet_bulb_temperature_2m_mean',
# ...

# %%
# Out:
# Empty DataFrame
# ...
